# %%
# !pip install pandas pymongo

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("./fake_data_final.csv")

# %%
df.head()
# Out:
#         Username User ID         Location               Model  \
# 0     brittany96   u0001  California, USA     Antminer S19 XP
# 1         john98   u0002     Georgia, USA  Antminer S19j Pro+
# 2  pearsonrobert   u0003      Nevada, USA   WhatsMiner M50S++
# 3   churchrobert   u0004      Nevada, USA        Antminer T21
# 4       enavarro   u0005  California, USA     WhatsMiner M60S
#
#    Hashrate (TH/s)  Power (W)  Efficiency (J/TH)  \
# 0              187       5345              28.58
# 1              213       6723              31.56
# 2               99       2682              27.09
# 3              198       5119              25.85
# 4              190       6038              31.78
#
#    Daily Rental Price ($/TH/s/day)  Estimated Total Daily Rental Price ($)  \
# 0                            0.047                                    8.79
# 1                            0.046                                    9.80
# ...

# %%
data = df.to_dict(orient="records")

# %%
data
# Out:
# [{'Username': 'brittany96',
#   'User ID': 'u0001',
#   'Location': 'California, USA',
#   'Model': 'Antminer S19 XP',
#   'Hashrate (TH/s)': 187,
#   'Power (W)': 5345,
#   'Efficiency (J/TH)': 28.58,
#   'Daily Rental Price ($/TH/s/day)': 0.047,
#   'Estimated Total Daily Rental Price ($)': 8.79,
#   'Estimated Hourly Rental Price ($)': 0.37},
#  {'Username': 'john98',
#   'User ID': 'u0002',
#   'Location': 'Georgia, USA',
#   'Model': 'Antminer S19j Pro+',
#   'Hashrate (TH/s)': 213,
#   'Power (W)': 6723,
#   'Efficiency (J/TH)': 31.56,
#   'Daily Rental Price ($/TH/s/day)': 0.046,
#   'Estimated Total Daily Rental Price ($)': 9.8,
#   'Estimated Hourly Rental Price ($)': 0.41},
#  {'Username': 'pearsonrobert',
#   'User ID': 'u0003',
#   'Location': 'Nevada, USA',
#   'Model': 'WhatsMiner M50S++',
#   'Hashrate (TH/s)': 99,
#   'Power (W)': 2682,
#   'Efficiency (J/TH)': 27.09,
#   'Daily Rental Price ($/TH/s/day)': 0.043,
#   'Estimated Total Daily Rental Price ($)': 4.26,
# ...

# %%
# Username: manjeshprasad21 Password for mongoDB 5G6k8TE4O6XXosdB

# %%
connection_string = "mongodb+srv://manjeshprasad21:5G6k8TE4O6XXosdB@cluster0.az7furc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
from pymongo import MongoClient, UpdateOne
